# %% [markdown]
# импорт библиотеки pandas и чтение csv файла

# %%
import pandas as pd

gods = pd.read_csv("greek_gods.csv")
gods
# Out:
#     name-english name-greek main-type  sub-type  \
# 0      Aphrodite   Ἀφροδίτη       god  olympian
# 1         Apollo    Ἀπόλλων       god  olympian
# 2           Ares       Ἄρης       god  olympian
# 3        Artemis    Ἄρτεμις       god  olympian
# 4         Athena      Ἀθηνᾶ       god  olympian
# ..           ...        ...       ...       ...
# 440       Rhapso       Ραψώ       god     nymph
# 441    Alexiares  Αλεξιαρης       god     other
# 442     Anicetus   Ανικητος       god     other
# 443      Auxesia    Αυξησία       god     other
# 444        Damia      Δαμία       god     other
#
#                                            description
# 0        goddess of beauty, love, desire, and pleasure
# 1    god of music, arts, knowledge, healing, plague...
# 2         god of courage, war, bloodshed, and violence
# 3    virgin goddess of the hunt, wilderness, animal...
# 4    goddess of reason, wisdom, intelligence, skill...
# ...

# %% [markdown]
# вывод первых 15 значений

# %%
gods.head(15)
# Out:
#    name-english name-greek main-type    sub-type  \
# 0     Aphrodite   Ἀφροδίτη       god    olympian
# 1        Apollo    Ἀπόλλων       god    olympian
# 2          Ares       Ἄρης       god    olympian
# 3       Artemis    Ἄρτεμις       god    olympian
# 4        Athena      Ἀθηνᾶ       god    olympian
# 5       Demeter    Δημήτηρ       god    olympian
# 6      Dionysus   Διόνυσος       god    olympian
# 7         Hades       ᾍδης       god    olympian
# 8    Hephaestus   Ἥφαιστος       god    olympian
# 9          Hera        Ἥρα       god    olympian
# 10       Hermes      Ἑρμῆς       god    olympian
# 11       Hestia      Ἑστία       god    olympian
# 12     Poseidon   Ποσειδῶν       god    olympian
# 13         Zeus       Ζεύς       god    olympian
# 14       Achlys      Ἀχλύς       god  primordial
#
#                                           description
# 0       goddess of beauty, love, desire, and pleasure
# 1   god of music, arts, knowledge, healing, plague...
# ...

# %% [markdown]
# вывод последних 15 значений

# %%
gods.tail(15)
# Out:
#     name-english  name-greek main-type sub-type  \
# 430  Terpsichore   Τερψιχόρη       god    other
# 431       Urania     Ουρανία       god    other
# 432     Cephisso     Κεφισσώ       god     muse
# 433    Apollonis   Απολλωνίς       god     muse
# 434  Borysthenis  Βορυσθενίς       god     muse
# 435       Hypate       Υπάτη       god     muse
# 436         Mese        Μέση       god     muse
# 437         Nete        Νήτη       god     muse
# 438  Polymatheia  Πολυμάθεια       god     muse
# 439    Palaestra   Παλαίστρα       god    other
# 440       Rhapso        Ραψώ       god    nymph
# 441    Alexiares   Αλεξιαρης       god    other
# 442     Anicetus    Ανικητος       god    other
# 443      Auxesia     Αυξησία       god    other
# 444        Damia       Δαμία       god    other
#
#                                            description
# 430                    muse of dance and choral poetry
# 431                                  muse of astronomy
# ...

# %% [markdown]
# анализ данных с помощью info

# %%
gods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name-english  445 non-null    object
#  1   name-greek    445 non-null    object
#  2   main-type     445 non-null    object
#  3   sub-type      445 non-null    object
#  4   description   445 non-null    object
# dtypes: object(5)
# memory usage: 17.5+ KB

# %% [markdown]
# вывод количества уникальных значений

# %%
gods.nunique()
# Out:
# name-english    445
# name-greek      441
# main-type         3
# sub-type         16
# description     395
# dtype: int64

# %%
gods["name-english"].nunique()
# Out:
# 445

# %%
gods["name-greek"].nunique()
# Out:
# 441

# %%
gods["main-type"].nunique()
# Out:
# 3

# %%
gods["sub-type"].nunique()
# Out:
# 16

# %%
gods["description"].nunique()
# Out:
# 395

# %% [markdown]
# фильтрация

# %%
gods.sort_values(by='sub-type')
# Out:
#     name-english   name-greek main-type      sub-type  \
# 341   Philomelus    Φιλόμελος       god   agriculture
# 342       Plutus      Πλοῦτος       god   agriculture
# 343  Triptolemus  Τριπτόλεμος       god   agriculture
# 340   Persephone    Περσεφόνη       god   agriculture
# 339     Eunostus     Εύνοστος       god   agriculture
# ..           ...          ...       ...           ...
# 41       Oceanus      Ὠκεανός     titan  twelve titan
# 42        Phoebe        Φοίβη     titan  twelve titan
# 43          Rhea          Ῥέα     titan  twelve titan
# 45         Theia         Θεία     titan  twelve titan
# 38      Hyperion      Ὑπερίων     titan  twelve titan
#
#                                            description
# 341  agricultural demi-god inventor of the wagon an...
# 342  god of wealth, including agricultural wealth, ...
# 343  god of farming and agriculture, he brought agr...
# 340  queen of the underworld, wife of hades and god...
# ...

# %%
gods[gods['main-type'] == 'god']
# Out:
#     name-english name-greek main-type  sub-type  \
# 0      Aphrodite   Ἀφροδίτη       god  olympian
# 1         Apollo    Ἀπόλλων       god  olympian
# 2           Ares       Ἄρης       god  olympian
# 3        Artemis    Ἄρτεμις       god  olympian
# 4         Athena      Ἀθηνᾶ       god  olympian
# ..           ...        ...       ...       ...
# 440       Rhapso       Ραψώ       god     nymph
# 441    Alexiares  Αλεξιαρης       god     other
# 442     Anicetus   Ανικητος       god     other
# 443      Auxesia    Αυξησία       god     other
# 444        Damia      Δαμία       god     other
#
#                                            description
# 0        goddess of beauty, love, desire, and pleasure
# 1    god of music, arts, knowledge, healing, plague...
# 2         god of courage, war, bloodshed, and violence
# 3    virgin goddess of the hunt, wilderness, animal...
# 4    goddess of reason, wisdom, intelligence, skill...
# ...

# %%
gods[gods['sub-type'] == 'nymph']
# Out:
#        name-english     name-greek main-type sub-type  \
# 186         Gorgyra        Γοργύρα       god    nymph
# 187          Orphne          Ορφνη       god    nymph
# 202        Eidothea        Ειδοθέα       god    nymph
# 205        Arethusa       Αρετούσα       god    nymph
# 206        Dynamene       Δυναμένη       god    nymph
# 207          Galene         Γαλήνη       god    nymph
# 208        Psamathe        Πσαμάθη       god    nymph
# 209          Thetis          Θέτις       god    nymph
# 210          Nereus         Νηρέας       god    nymph
# 212           Idyia          Ίδυια       god    nymph
# 261           Aurai  Αὖραι', 'Αὖρα       god    nymph
# 265  The Hesperides     ´Εσπερίδες       god    nymph
# 268         Nephele         Νεφέλη       god    nymph
# 281       Anthousai       Ανθούσαι       god    nymph
# 290         Chloris         Χλωρίς       god    nymph
# 304         Dryades        Δρυάδες       god    nymph
# ...

# %% [markdown]
# удаление дубликатов

# %%
deletedata = gods.drop_duplicates()

# %% [markdown]
# вывод уникальных значений

# %%
gods['main-type'].unique()
# Out:
# array(['god', 'titan', 'personification'], dtype=object)

# %%
gods['sub-type'].unique()
# Out:
# array(['olympian', 'primordial', 'twelve titan', 'other titan', 'other',
#        'personification', 'chthonic', 'nymph', 'sea', 'sky', 'rustic',
#        'agriculture', 'health', 'sleep', 'hours', 'muse'], dtype=object)

# %% [markdown]
# вывод размерности массива

# %%
gods.shape
# Out:
# (445, 5)

# %% [markdown]
# анализ с помощью describe

# %%
gods.describe()
# Out:
#        name-english name-greek main-type         sub-type  \
# count           445        445       445              445
# unique          445        441         3               16
# top       Aphrodite   Ἀστραῖος       god  personification
# freq              1          2       307              110
#
#                                               description
# count                                                 445
# unique                                                395
# top     sea spirit native to the island of rhodes (tel...
# freq                                                   16

# %%
gods.describe().count()
# Out:
# name-english    4
# name-greek      4
# main-type       4
# sub-type        4
# description     4
# dtype: int64

# %% [markdown]
# фильтрация датасета с помощью loc

# %%
locdata = gods.loc[0]
locdata
# Out:
# name-english                                        Aphrodite
# name-greek                                           Ἀφροδίτη
# main-type                                                 god
# sub-type                                             olympian
# description     goddess of beauty, love, desire, and pleasure
# Name: 0, dtype: object

# %%
rowdata = gods.loc[[0, 1, 2], ['name-english', 'name-greek']]
rowdata
# Out:
#   name-english name-greek
# 0    Aphrodite   Ἀφροδίτη
# 1       Apollo    Ἀπόλλων
# 2         Ares       Ἄρης

# %%
olympians = gods.loc[gods['sub-type'] == 'olympian']
olympians
# Out:
#    name-english name-greek main-type  sub-type  \
# 0     Aphrodite   Ἀφροδίτη       god  olympian
# 1        Apollo    Ἀπόλλων       god  olympian
# 2          Ares       Ἄρης       god  olympian
# 3       Artemis    Ἄρτεμις       god  olympian
# 4        Athena      Ἀθηνᾶ       god  olympian
# 5       Demeter    Δημήτηρ       god  olympian
# 6      Dionysus   Διόνυσος       god  olympian
# 7         Hades       ᾍδης       god  olympian
# 8    Hephaestus   Ἥφαιστος       god  olympian
# 9          Hera        Ἥρα       god  olympian
# 10       Hermes      Ἑρμῆς       god  olympian
# 11       Hestia      Ἑστία       god  olympian
# 12     Poseidon   Ποσειδῶν       god  olympian
# 13         Zeus       Ζεύς       god  olympian
#
#                                           description
# 0       goddess of beauty, love, desire, and pleasure
# 1   god of music, arts, knowledge, healing, plague...
# 2        god of courage, war, bloodshed, and violence
# ...

# %% [markdown]
# удаление колонки

# %%
deldata = deletedata.drop(columns=['description'])

# %% [markdown]
# замена значений в определенном столбце

# %%
rep = deldata.replace({'sub-type' : 'other'}, 'unknown')

# %% [markdown]
# сохранение нового датасета

# %%
rep.to_csv('newfile_gods.csv', index=False)

# %% [markdown]
# проверка нового датасета

# %%
readfl = pd.read_csv('newfile_gods.csv')
readfl
# Out:
#     name-english name-greek main-type  sub-type
# 0      Aphrodite   Ἀφροδίτη       god  olympian
# 1         Apollo    Ἀπόλλων       god  olympian
# 2           Ares       Ἄρης       god  olympian
# 3        Artemis    Ἄρτεμις       god  olympian
# 4         Athena      Ἀθηνᾶ       god  olympian
# ..           ...        ...       ...       ...
# 440       Rhapso       Ραψώ       god     nymph
# 441    Alexiares  Αλεξιαρης       god   unknown
# 442     Anicetus   Ανικητος       god   unknown
# 443      Auxesia    Αυξησία       god   unknown
# 444        Damia      Δαμία       god   unknown
#
# [445 rows x 4 columns]

# %% [markdown]
# вывод колонок

# %%
gods.columns
# Out:
# Index(['name-english', 'name-greek', 'main-type', 'sub-type', 'description'], dtype='object')
